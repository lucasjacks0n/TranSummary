# %%
from transummary import TranSummary

ts = TranSummary("https://www.youtube.com/watch?v=Xr1qrQzTViA")
data = ts.extract_data()
# Out:
# /home/lucaspy/miniconda3/envs/env1/lib/python3.10/site-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /home/lucaspy/miniconda3/envs/env1/lib/python3.10/site-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# [youtube] Extracting URL: https://youtube.com/watch?v=Xr1qrQzTViA
# [youtube] Xr1qrQzTViA: Downloading webpage
# [youtube] Xr1qrQzTViA: Downloading ios player API JSON
# [youtube] Xr1qrQzTViA: Downloading android player API JSON
# [youtube] Xr1qrQzTViA: Downloading m3u8 information
# [info] Xr1qrQzTViA: Downloading 1 format(s): 605+140
# [hlsnative] Downloading m3u8 manifest
# ...

# %%
data.get('videoId')
# Out:
# 'yXQSUEGWTpQ'

# %%
import pickle

cache_path = "/home/lucaspy/TranSummary/packages/api/src/cache/yXQSUEGWTpQ.pkl"
cache = None
with open(cache_path, "rb") as f:
    cache = pickle.loads(f.read())
   
with open(cache_path, 'wb') as f:
    cache['videoId'] = 'yXQSUEGWTpQ'
    f.write(pickle.dumps(cache))
